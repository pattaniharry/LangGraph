# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

llm = ChatGroq(
    model = "llama-3.1-8b-instant"
)

# %%
llm.invoke("what is the capital of IreLand?").content
# Out:
# 'The capital of Ireland is Dublin.'

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
myPrompt = ChatPromptTemplate.from_messages(
    [
        ("system", "you are a helpful assistant that helps to create a post about a topic "),
        ("human", "i wnat to create a post about {topic}")
    ]
)

# %%
chain = myPrompt | llm

# %%
chain.invoke("AI")
# Out:
# AIMessage(content="Here's a possible post on AI:\n\n**Title:** The Future of Artificial Intelligence: What You Need to Know\n\n**Introduction:**\n\nArtificial intelligence (AI) has revolutionized the way we live, work, and interact with each other. From virtual assistants to self-driving cars, AI is transforming industries and changing the world. In this post, we'll explore the latest developments in AI, its applications, and what the future holds for this rapidly evolving technology.\n\n**What is AI?**\n\nArtificial intelligence refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI systems use algorithms and data to make predictions, classify objects, and recognize patterns, among other tasks.\n\n**Types of AI:**\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI:** Designed to perform a specific task, such as playing chess or recognizing faces.\n2. **General or Strong AI:** A hypothetical AI system that possesses human-like intelligence and can perform any task that a human can.\n3. **Superintelligence:** An AI system that significantly surpasses human intelligence in all domains.\n\n**Applications of AI:**\n\nAI has numerous applications across various industries, including:\n\n1. **Healthcare:** AI is used in medical diagnosis, personalized medicine, and clinical decision support.\n2. **Finance:** AI is used in risk management, portfolio optimization, and customer service.\n3. **Transportation:** AI is used in self-driving cars, traffic management, and route optimization.\n4. **Education:** AI is used in personalized learning, grading, and course recommendation.\n\n**Benefits of AI:**\n\nThe benefits of AI include:\n\n1. **Increased Efficiency:** AI automates tasks, freeing up human resources for more strategic and creative work.\n2. **Improved Accuracy:** AI reduces errors and improves accuracy in tasks such as data analysis and decision-making.\n3. **Enhanced Customer Experience:** AI provides personalized recommendations and improved customer service.\n4. **New Business Opportunities:** AI enables the creation of new business models and revenue streams.\n\n**Challenges of AI:**\n\nWhile AI has numerous benefits, it also raises several challenges, including:\n\n1. **Job Displacement:** AI may displace certain jobs, particularly those that involve repetitive or routine tasks.\n2. **Bias and Fairness:** AI systems can perpetuate biases and discrimination if they are trained on biased data.\n3. **Security and Safety:** AI systems can be vulnerable to cyber attacks and pose safety risks if not properly designed and tested.\n4. **Ethics and Governance:** AI raises complex ethical and governance issues, including accountability and transparency.\n\n**Conclusion:**\n\nArtificial intelligence is a rapidly evolving technology that has the potential to transform industries and change the world. As AI continues to advance, it's essential to address the challenges and opportunities it presents. By understanding the benefits and limitations of AI, we can harness its potential to create a better future for all.\n\n**What do you think about AI? Share your thoughts in the comments below!**\n\nWould you like to add or remove anything from this post?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 632, 'prompt_tokens': 58, 'total_tokens': 690, 'completion_time': 1.139203886, 'completion_tokens_details': None, 'prompt_time': 0.002808336, 'prompt_tokens_details': None, 'queue_time': 0.046033814, 'total_time': 1.142012222}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d0036-d304-7371-8d24-29ca16ab0ad6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 632, 'total_tokens': 690})
