# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
llm = ChatGroq(
    model = "llama-3.1-8b-instant"
)
# Out:
# True

# %%
result = llm.invoke("who are you ")

print(result.content)
# Out:
# I'm an artificial intelligence model known as a large language model (LLM) or a conversational AI. I'm a computer program designed to understand and generate human-like text responses to a wide range of questions and topics.
#
# I don't have a personal identity or physical presence, but I exist solely as a digital entity. My purpose is to assist and provide information to users like you through text-based conversations.
#
# I've been trained on a massive dataset of text from various sources, including books, articles, and online content. This training allows me to learn patterns, relationships, and knowledge that I can use to generate responses to your questions and engage in conversations.
#
# Some of my capabilities include:
#
# 1. Answering questions on a wide range of topics, from science and history to entertainment and culture.
# 2. Generating text based on prompts or topics.
# 3. Summarizing long pieces of text into shorter, more digestible versions.
# 4. Translation of text from one language to another.
# 5. Offering suggestions and ideas based on your input.
#
# I'm constantly learning and improving, so if you have any specific topics or questions you'd like to discuss, feel free to ask me anything!

# %% [markdown]
# # First Graph

# %% [markdown]
# ## step 1 Define The Schema

# %%
from typing import TypedDict , List

class graph_schema(TypedDict):
    name : str
    message:str

# %% [markdown]
# ## step-2: Crete The Node Functions

# %%
def welcome(state:graph_schema) -> graph_schema:

    current_name = state['name']
    current_message = state['message']

    response = llm.invoke(f"my name is {current_name}.{current_message} ").content

    state['message'] = response

    return state

# %% [markdown]
# ## step-3 state Graph

# %%
from langgraph.graph import StateGraph , START, END

graph = StateGraph(graph_schema)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from langgraph.graph import StateGraph , START, END
# ----> 3 graph = StateGraph(graph_schema)
#
# NameError: name 'graph_schema' is not defined
